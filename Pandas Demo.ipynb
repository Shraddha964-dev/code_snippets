# %%
# https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ssaja\\OneDrive\\Desktop\\Courses & Project\\courses\\Python\\Numpy and Pandas'

# %%
# A Pandas DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns). 
# It is a fundamental data structure in the Pandas library, widely used for data manipulation, analysis, and cleaning. 


# CSV files are the Comma Separated Files. It allows users to load tabular data into a DataFrame, which is a powerful structure for data manipulation 
#and analysis. To access data from the CSV file, we require a function read_csv() from Pandas that retrieves data in the form of the data frame.

df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
# The .shape attribute in pandas is used to determine the dimensions of a DataFrame or Series. 
#It returns a tuple representing the number of rows and columns in the DataFrame, or the number of elements in a Series.
# 88883 rows, 85 columns

df.shape
# Out:
# (88883, 85)

# %%
'''
#The info() method in pandas is used to get a concise summary of a DataFrame. 
# It provides useful information about the DataFrame, including: 
Index dtype and column names:
.
Displays the data type of the index and the names of the columns in the DataFrame.
Non-null values:
.
Shows the number of non-null values in each column, which is useful for identifying missing data.
Data types:
.
Lists the data types of each column, such as int64, float64, object, etc.
Memory usage:
.
Provides an estimate of the memory usage of the DataFrame, which is helpful for optimizing memory usage when working with large datasets.
'''

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
# to see all 85 columns - have to chnage setting within jupyter
# pd.set_option('display.max_columns', 85) is a command used in the Python library Pandas. It configures the maximum number of columns that will be 
# displayed when printing a DataFrame.
# By default, Pandas might truncate the display of a DataFrame if it has many columns, showing only a limited number and replacing the rest with ellipses.
# This command changes that behavior, telling Pandas to display up to 85 columns. If a DataFrame has fewer than 85 columns, all of them will be shown. 
# If it has more, only the first 85 will be displayed.
# This setting is useful for viewing DataFrames with many columns, especially when exploring data or debugging code.

pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
#to see survey schema- column name here
schema_df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_schema.csv')

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88873       88062        NaN       No
# 88874       88076        NaN       No
# 88875       88182        NaN      Yes
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88873                                              Never
# 88874                                              Never
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
# to see all columns
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
# .value_counts(): Counts the number of times each unique value appears in that Series.
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
# used to access the row at index label 0 in the DataFrame df.
df.loc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
# just wanna see Hobbyist 
df.loc[0, 'Hobbyist']
# Out:
# 'Yes'

# %%
#first 3 responses for Hobbyist column
df.loc[[0,1,2], 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:2,'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:2,'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %% [markdown]
# # indexes

# %%
import pandas as pd

# %%
df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_public.csv')
schema_df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
# Respondent is actual index.
df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_public.csv', index_col = 'Respondent')
schema_df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_schema.csv')

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema_df.loc[70]
# Out:
# Column                                      SOAccount
# QuestionText    Do you have a Stack Overflow account?
# Name: 70, dtype: object

# %%
# Respondent is actual index.
df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_public.csv', index_col = 'Respondent')
schema_df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_schema.csv',index_col = 'Column')

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['MgrIdiot']
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index()
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
# reverse order
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
# its affecting the ascending order
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
# now its permantly in ascending order while inplace = True
schema_df.sort_index(inplace= True)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %% [markdown]
# # Filtering - Using Conditionals to Filter Rows and Columns

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
high_salary = df['ConvertedComp'] > 70000

# %%
df.loc[high_salary]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 13                             I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.loc[high_salary, ['Country','LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States','Canada','India','United Kingdom', 'Germany']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
# want to grab the languages worked with each person. we gonna use use string method .str
# also we have some NAN values so na= False i.e. part of contain method
filt = df['LanguageWorkedWith'].str.contains('Python', na= False)

# %%
df.loc[filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
# ...                                            ...      ...
# 84539                                          NaN      Yes
# 85738                                          NaN      Yes
# 86566                                          NaN      Yes
# 87739                                          NaN      Yes
# 88212                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...

# %%
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
filt
# Out:
# Respondent
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %% [markdown]
#  # Updating Rows and Columns - Modifying Data Within DataFrames

# %%
import pandas as pd

# %%
df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_public.csv', index_col = 'Respondent')
schema_df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_schema.csv',index_col = 'Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
# rename ConvertedComp(which is salary column) to salaryUSD with rename method
df.rename(columns ={'ConvertedComp' : 'SalaryUSD'})
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
# once that change looks good then after you make sure that it made the change that you wanted it to make 
# and that its not a mistake then we can apply to our dataframe.
df.rename(columns ={'ConvertedComp' : 'SalaryUSD'}, inplace = True)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
# convert Yes and NO values and map all of the Yes response to true - map method
df['Hobbyist'].map({'Yes':True, 'No':False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
# there is no inplace argument for map so set that series ans set that to equal to the mapped version
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True, 'No':False})

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
# remember when we use map than anything that isn't in our dictionary here so anything outside of a yes or no answer would
# be converetd to NaN value. 
# if we only wanted to converted yes or no values and leaves the others untouched then instaed map we could use replace method
# df['Hobbyist'] = df['Hobbyist'].replace({'Yes':True, 'No':False})

# %% [markdown]
# # Sorting

# %%
import pandas as pd

# %%
df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_public.csv', index_col = 'Respondent')
schema_df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_schema.csv',index_col = 'Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.sort_values(by='Country', inplace=True)

# %%
df['Country'].head(50)
# Out:
# Respondent
# 39258    Afghanistan
# 63129    Afghanistan
# 85715    Afghanistan
# 50767    Afghanistan
# 2782     Afghanistan
# 63019    Afghanistan
# 6417     Afghanistan
# 40000    Afghanistan
# 88731    Afghanistan
# 48436    Afghanistan
# 10746    Afghanistan
# 62525    Afghanistan
# 49702    Afghanistan
# 33178    Afghanistan
# 60946    Afghanistan
# 86362    Afghanistan
# 88582    Afghanistan
# 28638    Afghanistan
# 722      Afghanistan
# 26340    Afghanistan
# 86932    Afghanistan
# 85825    Afghanistan
# 7085     Afghanistan
# 7353     Afghanistan
# 87091    Afghanistan
# 58760    Afghanistan
# 74386    Afghanistan
# 29045    Afghanistan
# 51859    Afghanistan
# 45854    Afghanistan
# 47110    Afghanistan
# 44403    Afghanistan
# 22450    Afghanistan
# 8149     Afghanistan
# 80926    Afghanistan
# 59560    Afghanistan
# 60569    Afghanistan
# 37802    Afghanistan
# 29736    Afghanistan
# 43106    Afghanistan
# 12310    Afghanistan
# 58450    Afghanistan
# ...

# %%
df.sort_values(by=['Country','ConvertedComp'], ascending = [True,False], inplace=True)

# %%
df[['Country','ConvertedComp']].head(50)
# Out:
#                 Country  ConvertedComp
# Respondent
# 63129       Afghanistan      1000000.0
# 50499       Afghanistan       153216.0
# 39258       Afghanistan        19152.0
# 58450       Afghanistan        17556.0
# 7085        Afghanistan        14364.0
# 22450       Afghanistan         7980.0
# 48436       Afghanistan         4464.0
# 10746       Afghanistan         3996.0
# 8149        Afghanistan         1596.0
# 29736       Afghanistan         1116.0
# 28638       Afghanistan            0.0
# 722         Afghanistan            0.0
# 85715       Afghanistan            NaN
# 50767       Afghanistan            NaN
# 2782        Afghanistan            NaN
# 63019       Afghanistan            NaN
# 6417        Afghanistan            NaN
# 40000       Afghanistan            NaN
# 88731       Afghanistan            NaN
# 62525       Afghanistan            NaN
# 49702       Afghanistan            NaN
# 33178       Afghanistan            NaN
# 60946       Afghanistan            NaN
# ...

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, 'ConvertedComp')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      Yes
# 87896                          I am a developer by profession      Yes
# 22013                          I am a developer by profession      Yes
# 28243                          I am a developer by profession      Yes
# 72732       I am not primarily a developer, but I write co...       No
# 78151                          I am a developer by profession      Yes
# 80200                          I am a developer by profession      Yes
# 52132                          I am a developer by profession      Yes
# 75561                          I am a developer by profession      Yes
# 32250                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df.nsmallest(10, 'ConvertedComp')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 28638                          I am a developer by profession      Yes
# 722                            I am a developer by profession       No
# 13825                          I am a developer by profession      Yes
# 40913                          I am a developer by profession      Yes
# 30630                          I am a developer by profession      Yes
# 69049                          I am a developer by profession       No
# 19340       I am not primarily a developer, but I write co...      Yes
# 16214       I am not primarily a developer, but I write co...      Yes
# 29355                          I am a developer by profession      Yes
# 1685                           I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 28638       Less than once a month but more than once per ...
# ...

# %% [markdown]
# # Grouping and Aggregating - Analyzing and Exploring Your Data

# %%
df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_public.csv', index_col = 'Respondent')
schema_df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_schema.csv',index_col = 'Column')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[185], line 1
# ----> 1 df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_public.csv', index_col = 'Respondent')
#       2 schema_df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_schema.csv',index_col = 'Column')
#
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows',85)

# %%
df.head()

# %%
df['ConvertedComp'].head(15)

# %%
df['ConvertedComp'].median()

# %%
df.median()

# %%
df.describe()

# %%
# count you can see here that only about 55 thousand people answer that question. There are about 89 thousand rows for this data so that means that there 
# are about 30,000 people or so who didn't answer the salary question on this survey.

# most people think that count function will count up the individual values in a specific row and report how many of those values were in the column.
df['ConvertedComp'].count()

# %%
df['Hobbyist']

# %%
df['Hobbyist'].value_counts()

# %%
df['SocialMedia']

# %%
schema_df.loc['SocialMedia']

# %%
# which socialMedia popular
df['SocialMedia'].value_counts()

# %%
# to see these broken down by percentage instaed of row numbers
df['SocialMedia'].value_counts(normalize=True)

# %%
# group by operator involves some combination spilting the object, Apply function, comibine result
df['Country'].value_counts()

# %%
# how to use group by on country col
# spilt the object
country_grp = df.groupby(['Country'])

#DataFrameGroupBy object contain bunch of group.

# %%
country_grp.get_group('United States')

# %%
filt = df['Country'] == 'United States'
df.loc[filt]

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['SocialMedia'].value_counts()

# %%
filt = df['Country'] == 'India'
df.loc[filt]['SocialMedia'].value_counts()

# %%
# groupby object
country_grp['SocialMedia'].value_counts()

# %%
country_grp['SocialMedia'].value_counts().head(50)

# %%
# grab only for India
country_grp['SocialMedia'].value_counts().loc['India']

# %%
# count in percentage
country_grp['SocialMedia'].value_counts(normalize=True).loc['India'] # it will give in %

# %%
# aggregate functions: mean, median
# get all countries median
country_grp['ConvertedComp'].median()

# %%
# grab specific country 
country_grp['ConvertedComp'].median().loc['Germany']

# %%
# median and mean - more than one aggregate function
country_grp['ConvertedComp'].agg(['median','mean'])

# %%
# particular country
country_grp['ConvertedComp'].agg(['median','mean']).loc['Canada']

# %%
# trying to figure out how many people in each country know how to use python
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()

# %%
# median salary for country
country_grp['ConvertedComp'].median()

# %%
# median salary for germany
country_grp['ConvertedComp'].median().loc['Germany']

# %%
country_grp['ConvertedComp'].agg(['median','mean'])

# %%
country_grp['ConvertedComp'].agg(['median','mean']).loc['Canada']

# %%
# how many people in each country know how to use python
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum() )

# %%
#what % of people from each country know python?

# %%
country_respondents = df['Country'].value_counts()
country_respondents

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum() )
country_uses_python

# %%
# axis - bydefalut it will concat in rows so column
# 
python_df = pd.concat([country_respondents, country_uses_python], axis= 'columns', sort=False)
python_df

# %%
# rename columns
python_df.rename(columns={'count' : 'NumRespondents', 'LanguageWorkedWith' :'NumKnowsPython'}, inplace = True)

# %%
python_df

# %%
python_df['PctKnowsPython'] = (python_df['NumRespondents']/python_df['NumKnowsPython']) *100 
python_df

# %%
# sort this largest % who knows python
python_df.sort_values(by ='PctKnowsPython', ascending = False)

# %%
python_df.sort_values(by ='PctKnowsPython', ascending = False, inplace = True)

# %%
python_df.head(50)

# %%
python_df.loc['Japan']

# %% [markdown]
# # Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
import pandas as pd

# %%
df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_public.csv', index_col = 'Respondent')
schema_df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_schema.csv',index_col = 'Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()

# %%
# want to ignore custom values when loading in a csv
na_vals = ['NA', 'Missing'] # if the CSV file contains 'NA' or 'Missing' in any cell, pandas will automatically convert those to NaN.
df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_public.csv', index_col = 'Respondent', na_values = na_vals)
schema_df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_schema.csv',index_col = 'Column')

# %%
df.head()

# %%
# avarage number of coding experience
# lets see y its difficult:
df['YearsCode'].head(10)

# %%
df['YearsCode'].mean()

# %%
# to convert this to float then take avarage
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
# YearsCode column contain nan, numbers, str values
# if you want to see unique value
df['YearsCode'].unique()

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)

# %%
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'].unique()

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()

# %%
df['YearsCode'].median()

# %% [markdown]
# # Working with Dates and Time Series Data

# %%
import pandas as pd

# %%
df = pd.read_csv('data/ETH_1h.csv')

# %%
df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df.shape
# Out:
# (23674, 7)

# %%
df.loc[0, 'Date']
# Out:
# '2020-03-13 08-PM'

# %%
df.loc[0, 'Date'].day_name() # coz now this we are reading as string not date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.loc[0, 'Date'].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\ssaja\AppData\Local\Temp\ipykernel_6128\2394721818.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df['Date'] = pd.to_datetime(df['Date'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
# refer https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
# pd.to_datetime() is the pandas function used to convert a column or Series to datetime format. 
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d %I-%p')

# %%
df['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
# This directly accesses the value at row 0 and column 'Date'.

# Returns a single value (a Timestamp or datetime object).

# You then call .day_name() on that single datetime object.

df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
df.loc[0].Date.day_name()
# Out:
# 'Friday'

# %%
# here, we converted this to a date after we loaded in our data with pd.to_datetime() but if we wanna convert this to a date 
# as we're loading in our data

#df = pd.read_csv('data/ETH_1h.csv', parse_date = ['Date'])

# if your dates are already formatted in a way that pandas can parse them then you don't need to add anything else here
# but we already saw before that we need to pass in a specific format. 
# To do this, we can't just pass in a format string, we instead need to pass in a function that converts each string to date/time object

# create a function
d_parser = lambda x: pd.to_datetime(x, format='%Y-%m-%d %I-%p')
df = pd.read_csv('data/ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)
# Out:
# C:\Users\ssaja\AppData\Local\Temp\ipykernel_6128\1296748307.py:12: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv('data/ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)

# %%
df['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
# .dt is an accessor that allows you to apply datetime-related methods to a Pandas Series of datetime objects.
df['DayOfWeek'] = df['Date'].dt.day_name()

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
# time between dates
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt= (df['Date'] >= '2020' )
df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#       DayOfWeek
# 0        Friday
# ...

# %%
filt= (df['Date'] >= '2019' ) & (df['Date'] < '2020' )
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
# we were using str but we can use actaul datetime. 
filt = (df['Date'] >= pd.to_datetime('2019-01-01')) & (df['Date'] < pd.to_datetime('2020-01-01'))
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
df.set_index('Date',inplace=True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
df.loc['2019']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     DayOfWeek
# Date
# 2019-12-31 23:00:00   Tuesday
# ...

# %%
df['2020-01':'2020-02']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df['2020-01':'2020-02']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4085, in DataFrame.__getitem__(self, key)
#    4083 # Do we have a slicer (on rows)?
#    4084 if isinstance(key, slice):
# -> 4085     return self._getitem_slice(key)
#    4087 # Do we have a (boolean) DataFrame?
#    4088 if isinstance(key, DataFrame):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4349, in NDFrame._getitem_slice(self, key)
#    4344 """
#    4345 __getitem__ for the case where the key is a slice object.
#    4346 """
#    4347 # _convert_slice_indexer to determine if this slice is positional
#    4348 #  or label based, and if the latter, convert to positional
# -> 4349 slobj = self.index._convert_slice_indexer(key, kind="getitem")
#    4350 if isinstance(slobj, np.ndarray):
# ...

# %%
# Partial datetime slicing like '2020-01':'2020-02' only works if the index is:

#A DatetimeIndex

#Sorted in ascending order (monotonic)

# If the index is unsorted or not a datetime, you’ll get a KeyError.

df = df.sort_index()

df['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# ...                     ...     ...     ...     ...     ...         ...
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
#
#                      DayOfWeek
# Date
# 2020-01-01 00:00:00  Wednesday
# ...

# %%
df = df.sort_index()

df['2020-01':'2020-02']['Close']
# Out:
# Date
# 2020-01-01 00:00:00    128.34
# 2020-01-01 01:00:00    130.14
# 2020-01-01 02:00:00    130.37
# 2020-01-01 03:00:00    129.57
# 2020-01-01 04:00:00    129.56
#                         ...
# 2020-02-29 19:00:00    225.31
# 2020-02-29 20:00:00    224.63
# 2020-02-29 21:00:00    223.48
# 2020-02-29 22:00:00    223.35
# 2020-02-29 23:00:00    217.31
# Name: Close, Length: 1440, dtype: float64

# %%
# avarage closing price for all of those rows within that time period 
df = df.sort_index()

df['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.1655902777778

# %%
# We wonna see high value for that day

df.loc['2020-01-01']['High'].max()
# Out:
# 132.68

# %%
df['High'].resample('D').max()
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
highs = df['High'].resample('D').max()
highs['2020-01-01']
# Out:
# 132.68

# %%
import matplotlib
# %matplotlib inline

# %%
highs.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.resample('W').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %% [markdown]
# # Reading/Writing Data to Different Sources - Excel, JSON, SQL, Etc

# %%
df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_public.csv', index_col = 'Respondent')
schema_df = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_schema.csv',index_col = 'Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
# if you want to export this into csv file
india_df.to_csv('data/modified.csv')

# %%
# sep : seperator
india_df.to_csv('data/modified.tsv', sep='\t')

# %%
# we gonna write in excel, we're going to pip install a couple packages so install

# pip install xlwt openpyxl xlrd

india_df.to_excel('data/modified.xlsx')

# %%
test = pd.read_excel('data/modified.xlsx', index_col='Respondent')

# %%
test.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
india_df.to_json('data/modified.json')

# %%
# if json we want in list like, instead of dict - we can orient argument 
india_df.to_json('data/modified.json', orient = 'records', ines= True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # if json we want in list like, instead of dict - we can orient argument
# ----> 2 india_df.to_json('data/modified.json', orient = 'records', ines= True)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# TypeError: NDFrame.to_json() got an unexpected keyword argument 'ines'
